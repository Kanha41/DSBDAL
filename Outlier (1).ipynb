# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/KANHAIYA/OneDrive/Documents/Attachments/Desktop/dsbda2/book2.csv")

# %%
df.head()
# Out:
#    Math Score  Reading score  Writing score  placement score  club Join year  \
# 0          69             83           67.0             96.0          2024.0
# 1          66             83           79.0             79.0          2020.0
# 2          76             87           61.0             96.0          2026.0
# 3          63             89           75.0             92.0          2026.0
# 4          68             97           63.0             99.0          2021.0
#
#    placement offer count
# 0                      3
# 1                      2
# 2                      3
# 3                      3
# 4                      3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Math Score             39 non-null     int64
#  1   Reading score          39 non-null     int64
#  2   Writing score          37 non-null     float64
#  3   placement score        33 non-null     float64
#  4   club Join year         34 non-null     float64
#  5   placement offer count  39 non-null     int64
# dtypes: float64(3), int64(3)
# memory usage: 2.0 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Math Score             39 non-null     int64
#  1   Reading score          39 non-null     int64
#  2   Writing score          37 non-null     float64
#  3   placement score        33 non-null     float64
#  4   club Join year         34 non-null     float64
#  5   placement offer count  39 non-null     int64
# dtypes: float64(3), int64(3)
# memory usage: 2.0 KB

# %%
df.describe()
# Out:
#        Math Score  Reading score  Writing score  placement score  \
# count   39.000000      39.000000      37.000000        33.000000
# mean    67.384615      83.076923      69.459459        87.515152
# std      5.363696       5.873153       6.094600         8.197260
# min     60.000000      75.000000      60.000000        75.000000
# 25%     63.000000      78.500000      65.000000        80.000000
# 50%     67.000000      83.000000      71.000000        87.000000
# 75%     69.000000      87.000000      75.000000        95.000000
# max     80.000000      99.000000      80.000000       105.000000
#
#        club Join year  placement offer count
# count       34.000000              39.000000
# mean      2022.411765               2.333333
# std          4.425256               0.737468
# min       2000.000000               1.000000
# 25%       2022.000000               2.000000
# 50%       2022.000000               2.000000
# 75%       2024.750000               3.000000
# ...

# %%
df.notnull().sum()
# Out:
# Math Score               39
# Reading score            39
# Writing score            37
# placement score          33
# club Join year           34
# placement offer count    39
# dtype: int64

# %%
df.columns
# Out:
# Index(['Math Score', 'Reading score', 'Writing score', 'placement score',
#        'club Join year', 'placement offer count'],
#       dtype='object')

# %%
df
# Out:
#     Math Score  Reading score  Writing score  placement score  club Join year  \
# 0           69             83           67.0             96.0          2024.0
# 1           66             83           79.0             79.0          2020.0
# 2           76             87           61.0             96.0          2026.0
# 3           63             89           75.0             92.0          2026.0
# 4           68             97           63.0             99.0          2021.0
# 5           61             86           72.0            100.0          2021.0
# 6           68             84           76.0             82.0          2025.0
# 7           79             90           66.0             78.0          2022.0
# 8           65             77           67.0             93.0          2026.0
# 9           72             89           65.0             75.0          2020.0
# 10          60             89           60.0             78.0          2024.0
# ...

# %%
df.drop([20,21,22],inplace=True)

# %%
df
# Out:
#     Math Score  Reading score  Writing score  placement score  club Join year  \
# 0           69             83           67.0             96.0          2024.0
# 1           66             83           79.0             79.0          2020.0
# 2           76             87           61.0             96.0          2026.0
# 3           63             89           75.0             92.0          2026.0
# 4           68             97           63.0             99.0          2021.0
# 5           61             86           72.0            100.0          2021.0
# 6           68             84           76.0             82.0          2025.0
# 7           79             90           66.0             78.0          2022.0
# 8           65             77           67.0             93.0          2026.0
# 9           72             89           65.0             75.0          2020.0
# 10          60             89           60.0             78.0          2024.0
# ...

# %%
df.isna().sum()
# Out:
# Math Score               0
# Reading score            0
# Writing score            2
# placement score          3
# club Join year           2
# placement offer count    0
# dtype: int64

# %%
df["Writing score"] = (
    df["Writing score"]
    .fillna(df["Writing score"].mean())
    .round()
    .astype(int)
)
df["placement score"] = (
    df["placement score"]
    .fillna(df["placement score"].mean())
    .round()
    .astype(int)
)

df["club Join year"] = (
    df["club Join year"]
    .fillna(df["club Join year"].mean())
    .round()
    .astype(int)
)

# %%
df
# Out:
#     Math Score  Reading score  Writing score  placement score  club Join year  \
# 0           69             83             67               96            2024
# 1           66             83             79               79            2020
# 2           76             87             61               96            2026
# 3           63             89             75               92            2026
# 4           68             97             63               99            2021
# 5           61             86             72              100            2021
# 6           68             84             76               82            2025
# 7           79             90             66               78            2022
# 8           65             77             67               93            2026
# 9           72             89             65               75            2020
# 10          60             89             60               78            2024
# ...

# %%
import matplotlib.pyplot as plt

col = ['Math Score', 'Reading score', 
       'Writing score', 'placement score']

plt.figure(figsize=(8,5))
df.boxplot(column=col)
plt.show()

# %%
print(np.where(df["Reading score"]>95))
# Out:
# (array([ 4, 21]),)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,5))

ax.scatter(df['placement score'], df['placement offer count'])

ax.set_xlabel("Placement Score")
ax.set_ylabel("Placement Offer Count")
ax.set_title("Placement Score vs Offer Count")

plt.show()

# %%
print(np.where((df['placement score'] < 50) & 
               (df['placement offer count'] > 1)))
# Out:
# (array([], dtype=int64),)

# %%
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(df['Math Score']))
print(z)
# Out:
# [0.39434447 0.19717223 1.77455011 0.78868894 0.19717223 1.1830334
#  0.19717223 2.36606681 0.39434447 0.98586117 1.38020564 0.19717223
#  0.         0.78868894 0.39434447 0.19717223 0.98586117 2.16889457
#  1.38020564 0.98586117 0.39434447 0.19717223 0.78868894 0.39434447
#  0.98586117 1.1830334  0.39434447 1.38020564 0.5915167  1.1830334
#  0.19717223 0.78868894 0.19717223 1.97172234 0.39434447 0.78868894]

# %%
threshold = 0.18

# %%
outliers=np.where(z<threshold)
outliers
# Out:
# (array([12]),)

# %%
sorted_rscore = sorted(df['Reading score'])
print(sorted_rscore)
# Out:
# [75, 75, 75, 76, 76, 77, 77, 78, 78, 79, 79, 79, 80, 80, 82, 82, 83, 83, 83, 83, 84, 85, 86, 86, 87, 87, 87, 88, 88, 89, 89, 89, 90, 90, 97, 99]

# %%
q1=np.percentile(sorted_rscore,25)
q3=np.percentile(sorted_rscore,75)

# %%
print(q1,q3)
# Out:
# 78.75 87.25

# %%
IQR = q3-q1

# %%
lwr_bound=q1-(1.5*IQR)
upr_bound=q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 66.0 100.0

# %%
r_outliers = []
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %%
col1 = ['Reading score']

plt.figure(figsize=(6,4))
df.boxplot(column=col1)
plt.title("Boxplot of Reading Score")
plt.show()

# %%
import matplotlib.pyplot as plt

df['Math Score'].plot(kind='hist', bins=10, figsize=(6,4))
plt.xlabel("Math Score")
plt.title("Histogram of Math Score")
plt.show()
